# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Maziar\Downloads\Compressed\archive\WA_Fn-UseC_-Telco-Customer-Churn.csv")

print("Shape:", df.shape)
print("\n--- Data Types ---")
print(df.dtypes)
print("\n--- First 5 Rows ---")
df.head()
# Out:
# Shape: (7043, 21)
#
# --- Data Types ---
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object
#
# --- First 5 Rows ---
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# ...

# %%
print("Duplicates:", df.duplicated().sum())
print("\n--- Missing Values ---")
print(df.isnull().sum())

print("\n--- Non-numeric values in TotalCharges ---")
print(df[pd.to_numeric(df['TotalCharges'], errors='coerce').isnull()]['TotalCharges'].value_counts())
# Out:
# Duplicates: 0
#
# --- Missing Values ---
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64
#
# --- Non-numeric values in TotalCharges ---
# TotalCharges
#     11
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].hist(df['tenure'], bins=30, color='steelblue', edgecolor='black')
axes[0].set_title('Distribution of Tenure')

axes[1].hist(df['MonthlyCharges'], bins=30, color='coral', edgecolor='black')
axes[1].set_title('Distribution of MonthlyCharges')

axes[2].hist(df['TotalCharges'].dropna(), bins=30, color='seagreen', edgecolor='black')
axes[2].set_title('Distribution of TotalCharges')

plt.tight_layout()
plt.show()

cat_cols = ['gender', 'Partner', 'Dependents', 'Contract', 'InternetService', 'Churn']
fig, axes = plt.subplots(2, 3, figsize=(16, 8))

for ax, col in zip(axes.flatten(), cat_cols):
    df[col].value_counts().plot(kind='bar', ax=ax, color='steelblue', edgecolor='black')
    ax.set_title(col)
    ax.set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
num_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

plt.figure(figsize=(8, 5))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(16, 4))
for ax, col in zip(axes, num_cols):
    sns.boxplot(x='Churn', y=col, data=df, ax=ax, palette='Set2')
    ax.set_title(f'{col} vs Churn')

plt.tight_layout()
plt.show()

# %%
print("Missing before fix:", df['TotalCharges'].isnull().sum())

df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)

print("Missing after fix:", df['TotalCharges'].isnull().sum())

df.drop('customerID', axis=1, inplace=True)

from sklearn.preprocessing import LabelEncoder, StandardScaler

binary_cols = ['gender', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling', 'Churn']
le = LabelEncoder()
for col in binary_cols:
    df[col] = le.fit_transform(df[col])

multi_cat_cols = ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
                  'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
                  'Contract', 'PaymentMethod']
df = pd.get_dummies(df, columns=multi_cat_cols, drop_first=True)

num_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

print("\nShape after preprocessing:", df.shape)
print("\n--- First 3 rows ---")
df.head(3)
